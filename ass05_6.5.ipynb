# %% [markdown]
# # 第五次作业_02_6.5

# %% [markdown]
# > 新雅62/CDIE6
# > 2016013327 项雨桐

# %% [markdown]
# ## 0. 导入包和数据

# %%
from skimage.io import ImageCollection
import numpy as np
import numpy.random as rand
import random
from sklearn.model_selection import train_test_split
from  sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %%
rand.seed(15)
path = 'HomeworkData/Pictures/'

# %% [markdown]
# ## 1. 数据准备

# %%
def image_read(index):
    full_path = path + str(index) + '/*.png' 
    data = ImageCollection(full_path, as_gray=True).concatenate()
    data = data.reshape(-1,(data.shape[1]*data.shape[2]))
    data = np.concatenate((data, index * np.ones((data.shape[0],1))), axis = 1)
    return data

def data_preparation(data_all, num):
    data_sam = random.sample(data_all, num)
    data_sam = np.asarray(data_sam)
    data_sam = data_sam.reshape((data_sam.shape[0]*data_sam.shape[1]),-1)
    data_X = data_sam[:,:-1]
    data_y = data_sam[:,-1]
    X_train, X_test, y_train, y_test = train_test_split(data_X, data_y, train_size=0.75)
    return X_train, X_test, y_train, y_test

# %%
data_0 = image_read(0)
data_1 = image_read(1)
data_2 = image_read(2)
data_3 = image_read(3)
data_4 = image_read(4)
data_5 = image_read(5)
data_6 = image_read(6)
data_7 = image_read(7)
data_8 = image_read(8)
data_9 = image_read(9)

data_all = [data_0, data_1 ,data_2 ,data_3 ,data_4 ,data_5 ,data_6 ,data_7 ,data_8 ,data_9]

X_2_train, X_2_test, y_2_train, y_2_test = data_preparation(data_all,2)
X_5_train, X_5_test, y_5_train, y_5_test = data_preparation(data_all,5)
X_10_train, X_10_test, y_10_train, y_10_test = data_preparation(data_all,10)

# %% [markdown]
# ## 2. 模型预测

# %%
model_2 = RFC().fit(X_2_train,y_2_train)
model_5 = RFC().fit(X_5_train,y_5_train)
model_10 = RFC().fit(X_10_train,y_10_train)

y_2_pred = model_2.predict(X_2_test)
y_2_prob = (model_2.predict_proba(X_2_test)[:,1])
y_5_pred = model_5.predict(X_5_test)
y_10_pred = model_10.predict(X_10_test)

# %% [markdown]
# ## 3. 模型评价

# %%
acc_2 = accuracy_score(y_2_test,y_2_pred)
acc_5 = accuracy_score(y_5_test,y_5_pred)
acc_10 = accuracy_score(y_10_test,y_10_pred)

TN, FP, FN, TP = confusion_matrix(y_2_test,y_2_pred).ravel()
TPR = TP/(TP+FN)
FPR = FP/(FP+TN)
TNR = TN/(TN+FP)
FNR = FN/(FN+TP)
sensitivity = TP/(TP+FN)
specificity = TN/(TN+FP)
FDR = FP/(FP+TP)

print("测试准确率:")
print("2分类: " + str(round(acc_2, 4)))
print("5分类: " + str(round(acc_5, 4)))
print("10分类: " + str(round(acc_10, 4)))
print("2分类性能参数:")
print("TPR: " + str(round(TPR, 4)))
print("FPR: " + str(round(FPR, 4)))
print("TNR: " + str(round(TNR, 4)))
print("FNR: " + str(round(FNR, 4)))
print("sensitivity: " + str(round(sensitivity, 4)))
print("specificity: " + str(round(specificity, 4)))
print("FDR: " + str(round(FDR, 4)))

# %%
AUC = roc_auc_score(y_2_test, y_2_prob)
print("AUC: " + str(round(AUC, 4)))

fpr,tpr,th = roc_curve(y_2_test, y_2_prob, pos_label = max(y_2_test))
plt.title('ROC')
plt.plot(fpr,tpr,'b')
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.show()

# %% [markdown]
# ## 4. 不同树的个数

# %%
model_10_25 = RFC(n_estimators=25).fit(X_10_train,y_10_train)
model_10_50 = RFC(n_estimators=50).fit(X_10_train,y_10_train)
model_10_250 = RFC(n_estimators=250).fit(X_10_train,y_10_train)
model_10_500 = RFC(n_estimators=500).fit(X_10_train,y_10_train)
model_10_1000 = RFC(n_estimators=1000).fit(X_10_train,y_10_train)

# %%
y_10_25_pred = model_10_25.predict(X_10_train)
y_10_50_pred = model_10_50.predict(X_10_train)
y_10_100_pred = model_10.predict(X_10_train)
y_10_250_pred = model_10_250.predict(X_10_train)
y_10_500_pred = model_10_500.predict(X_10_train)
y_10_1000_pred = model_10_1000.predict(X_10_train)

acc_25 = accuracy_score(y_10_train,y_10_25_pred)
acc_50 = accuracy_score(y_10_train,y_10_50_pred)
acc_100 = accuracy_score(y_10_train,y_10_100_pred)
acc_250 = accuracy_score(y_10_train,y_10_250_pred)
acc_500 = accuracy_score(y_10_train,y_10_500_pred)
acc_1000 = accuracy_score(y_10_train,y_10_1000_pred)

# %%
print("训练准确率: ")
print("n=25: ",acc_25)
print("n=50: ",acc_50)
print("n=100: ",acc_100)
print("n=250: ",acc_250)
print("n=500: ",acc_500)
print("n=1000: ",acc_1000)

print("测试准确率: ")
print("n=25: ", model_10_25.score(X_10_test,y_10_test))
print("n=50: ", model_10_50.score(X_10_test,y_10_test))
print("n=100: ", model_10.score(X_10_test,y_10_test))
print("n=250: ", model_10_250.score(X_10_test,y_10_test))
print("n=500: ", model_10_500.score(X_10_test,y_10_test))
print("n=1000: ", model_10_1000.score(X_10_test,y_10_test))

# %% [markdown]
# ## 5. 树的最大深度

# %%
model_10_d5 = RFC(n_estimators=1000, max_depth=5).fit(X_10_train,y_10_train)
model_10_d10 = RFC(n_estimators=1000, max_depth=10).fit(X_10_train,y_10_train)
model_10_d20 = RFC(n_estimators=1000, max_depth=20).fit(X_10_train,y_10_train)
model_10_d50 = RFC(n_estimators=1000, max_depth=50).fit(X_10_train,y_10_train)
model_10_d100 = RFC(n_estimators=1000, max_depth=100).fit(X_10_train,y_10_train)

# %%
print("d=5: ", model_10_d5.score(X_10_test,y_10_test))
print("d=10: ", model_10_d10.score(X_10_test,y_10_test))
print("d=20: ", model_10_d20.score(X_10_test,y_10_test))
print("d=50: ", model_10_d50.score(X_10_test,y_10_test))
print("d=100: ", model_10_d100.score(X_10_test,y_10_test))
